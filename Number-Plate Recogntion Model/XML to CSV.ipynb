# %%
import pandas as pd
import xml.etree.ElementTree as xet

# %%
from glob import glob

# %%
path = glob("./archive (1)/annotations/*.xml")
path
# Out:
# ['./archive (1)/annotations\\Cars0.xml',
#  './archive (1)/annotations\\Cars1.xml',
#  './archive (1)/annotations\\Cars10.xml',
#  './archive (1)/annotations\\Cars100.xml',
#  './archive (1)/annotations\\Cars101.xml',
#  './archive (1)/annotations\\Cars102.xml',
#  './archive (1)/annotations\\Cars103.xml',
#  './archive (1)/annotations\\Cars104.xml',
#  './archive (1)/annotations\\Cars105.xml',
#  './archive (1)/annotations\\Cars106.xml',
#  './archive (1)/annotations\\Cars107.xml',
#  './archive (1)/annotations\\Cars108.xml',
#  './archive (1)/annotations\\Cars109.xml',
#  './archive (1)/annotations\\Cars11.xml',
#  './archive (1)/annotations\\Cars110.xml',
#  './archive (1)/annotations\\Cars111.xml',
#  './archive (1)/annotations\\Cars112.xml',
#  './archive (1)/annotations\\Cars113.xml',
#  './archive (1)/annotations\\Cars114.xml',
#  './archive (1)/annotations\\Cars115.xml',
#  './archive (1)/annotations\\Cars116.xml',
#  './archive (1)/annotations\\Cars117.xml',
#  './archive (1)/annotations\\Cars118.xml',
#  './archive (1)/annotations\\Cars119.xml',
#  './archive (1)/annotations\\Cars12.xml',
#  './archive (1)/annotations\\Cars120.xml',
#  './archive (1)/annotations\\Cars121.xml',
#  './archive (1)/annotations\\Cars122.xml',
#  './archive (1)/annotations\\Cars123.xml',
#  './archive (1)/annotations\\Cars124.xml',
#  './archive (1)/annotations\\Cars125.xml',
#  './archive (1)/annotations\\Cars126.xml',
#  './archive (1)/annotations\\Cars127.xml',
#  './archive (1)/annotations\\Cars128.xml',
#  './archive (1)/annotations\\Cars129.xml',
#  './archive (1)/annotations\\Cars13.xml',
#  './archive (1)/annotations\\Cars130.xml',
#  './archive (1)/annotations\\Cars131.xml',
#  './archive (1)/annotations\\Cars132.xml',
#  './archive (1)/annotations\\Cars133.xml',
#  './archive (1)/annotations\\Cars134.xml',
#  './archive (1)/annotations\\Cars135.xml',
#  './archive (1)/annotations\\Cars136.xml',
#  './archive (1)/annotations\\Cars137.xml',
#  './archive (1)/annotations\\Cars138.xml',
#  './archive (1)/annotations\\Cars139.xml',
#  './archive (1)/annotations\\Cars14.xml',
#  './archive (1)/annotations\\Cars140.xml',
#  './archive (1)/annotations\\Cars141.xml',
#  './archive (1)/annotations\\Cars142.xml',
#  './archive (1)/annotations\\Cars143.xml',
#  './archive (1)/annotations\\Cars144.xml',
#  './archive (1)/annotations\\Cars145.xml',
#  './archive (1)/annotations\\Cars146.xml',
#  './archive (1)/annotations\\Cars147.xml',
#  './archive (1)/annotations\\Cars148.xml',
#  './archive (1)/annotations\\Cars149.xml',
#  './archive (1)/annotations\\Cars15.xml',
#  './archive (1)/annotations\\Cars150.xml',
#  './archive (1)/annotations\\Cars151.xml',
#  './archive (1)/annotations\\Cars152.xml',
#  './archive (1)/annotations\\Cars153.xml',
#  './archive (1)/annotations\\Cars154.xml',
#  './archive (1)/annotations\\Cars155.xml',
#  './archive (1)/annotations\\Cars156.xml',
#  './archive (1)/annotations\\Cars157.xml',
#  './archive (1)/annotations\\Cars158.xml',
#  './archive (1)/annotations\\Cars159.xml',
#  './archive (1)/annotations\\Cars16.xml',
#  './archive (1)/annotations\\Cars160.xml',
#  './archive (1)/annotations\\Cars161.xml',
#  './archive (1)/annotations\\Cars162.xml',
#  './archive (1)/annotations\\Cars163.xml',
#  './archive (1)/annotations\\Cars164.xml',
#  './archive (1)/annotations\\Cars165.xml',
#  './archive (1)/annotations\\Cars166.xml',
#  './archive (1)/annotations\\Cars167.xml',
#  './archive (1)/annotations\\Cars168.xml',
#  './archive (1)/annotations\\Cars169.xml',
#  './archive (1)/annotations\\Cars17.xml',
#  './archive (1)/annotations\\Cars170.xml',
#  './archive (1)/annotations\\Cars171.xml',
#  './archive (1)/annotations\\Cars172.xml',
#  './archive (1)/annotations\\Cars173.xml',
#  './archive (1)/annotations\\Cars174.xml',
#  './archive (1)/annotations\\Cars175.xml',
#  './archive (1)/annotations\\Cars176.xml',
#  './archive (1)/annotations\\Cars177.xml',
#  './archive (1)/annotations\\Cars178.xml',
#  './archive (1)/annotations\\Cars179.xml',
#  './archive (1)/annotations\\Cars18.xml',
#  './archive (1)/annotations\\Cars180.xml',
#  './archive (1)/annotations\\Cars181.xml',
#  './archive (1)/annotations\\Cars182.xml',
#  './archive (1)/annotations\\Cars183.xml',
#  './archive (1)/annotations\\Cars184.xml',
#  './archive (1)/annotations\\Cars185.xml',
#  './archive (1)/annotations\\Cars186.xml',
#  './archive (1)/annotations\\Cars187.xml',
#  './archive (1)/annotations\\Cars188.xml',
#  './archive (1)/annotations\\Cars189.xml',
#  './archive (1)/annotations\\Cars19.xml',
#  './archive (1)/annotations\\Cars190.xml',
#  './archive (1)/annotations\\Cars191.xml',
#  './archive (1)/annotations\\Cars192.xml',
#  './archive (1)/annotations\\Cars193.xml',
#  './archive (1)/annotations\\Cars194.xml',
#  './archive (1)/annotations\\Cars195.xml',
#  './archive (1)/annotations\\Cars196.xml',
#  './archive (1)/annotations\\Cars197.xml',
#  './archive (1)/annotations\\Cars198.xml',
#  './archive (1)/annotations\\Cars199.xml',
#  './archive (1)/annotations\\Cars2.xml',
#  './archive (1)/annotations\\Cars20.xml',
#  './archive (1)/annotations\\Cars200.xml',
#  './archive (1)/annotations\\Cars201.xml',
#  './archive (1)/annotations\\Cars202.xml',
#  './archive (1)/annotations\\Cars203.xml',
#  './archive (1)/annotations\\Cars204.xml',
#  './archive (1)/annotations\\Cars205.xml',
#  './archive (1)/annotations\\Cars206.xml',
#  './archive (1)/annotations\\Cars207.xml',
#  './archive (1)/annotations\\Cars208.xml',
#  './archive (1)/annotations\\Cars209.xml',
#  './archive (1)/annotations\\Cars21.xml',
#  './archive (1)/annotations\\Cars210.xml',
#  './archive (1)/annotations\\Cars211.xml',
#  './archive (1)/annotations\\Cars212.xml',
#  './archive (1)/annotations\\Cars213.xml',
#  './archive (1)/annotations\\Cars214.xml',
#  './archive (1)/annotations\\Cars215.xml',
#  './archive (1)/annotations\\Cars216.xml',
#  './archive (1)/annotations\\Cars217.xml',
#  './archive (1)/annotations\\Cars218.xml',
#  './archive (1)/annotations\\Cars219.xml',
#  './archive (1)/annotations\\Cars22.xml',
#  './archive (1)/annotations\\Cars220.xml',
#  './archive (1)/annotations\\Cars221.xml',
#  './archive (1)/annotations\\Cars222.xml',
#  './archive (1)/annotations\\Cars223.xml',
#  './archive (1)/annotations\\Cars224.xml',
#  './archive (1)/annotations\\Cars225.xml',
#  './archive (1)/annotations\\Cars226.xml',
#  './archive (1)/annotations\\Cars227.xml',
#  './archive (1)/annotations\\Cars228.xml',
#  './archive (1)/annotations\\Cars229.xml',
#  './archive (1)/annotations\\Cars23.xml',
#  './archive (1)/annotations\\Cars230.xml',
#  './archive (1)/annotations\\Cars231.xml',
#  './archive (1)/annotations\\Cars232.xml',
#  './archive (1)/annotations\\Cars233.xml',
#  './archive (1)/annotations\\Cars234.xml',
#  './archive (1)/annotations\\Cars235.xml',
#  './archive (1)/annotations\\Cars236.xml',
#  './archive (1)/annotations\\Cars237.xml',
#  './archive (1)/annotations\\Cars238.xml',
#  './archive (1)/annotations\\Cars239.xml',
#  './archive (1)/annotations\\Cars24.xml',
#  './archive (1)/annotations\\Cars240.xml',
#  './archive (1)/annotations\\Cars241.xml',
#  './archive (1)/annotations\\Cars242.xml',
#  './archive (1)/annotations\\Cars243.xml',
#  './archive (1)/annotations\\Cars244.xml',
#  './archive (1)/annotations\\Cars245.xml',
#  './archive (1)/annotations\\Cars246.xml',
#  './archive (1)/annotations\\Cars247.xml',
#  './archive (1)/annotations\\Cars248.xml',
#  './archive (1)/annotations\\Cars249.xml',
#  './archive (1)/annotations\\Cars25.xml',
#  './archive (1)/annotations\\Cars250.xml',
#  './archive (1)/annotations\\Cars251.xml',
#  './archive (1)/annotations\\Cars252.xml',
#  './archive (1)/annotations\\Cars253.xml',
#  './archive (1)/annotations\\Cars254.xml',
#  './archive (1)/annotations\\Cars255.xml',
#  './archive (1)/annotations\\Cars256.xml',
#  './archive (1)/annotations\\Cars257.xml',
#  './archive (1)/annotations\\Cars258.xml',
#  './archive (1)/annotations\\Cars259.xml',
#  './archive (1)/annotations\\Cars26.xml',
#  './archive (1)/annotations\\Cars260.xml',
#  './archive (1)/annotations\\Cars261.xml',
#  './archive (1)/annotations\\Cars262.xml',
#  './archive (1)/annotations\\Cars263.xml',
#  './archive (1)/annotations\\Cars264.xml',
#  './archive (1)/annotations\\Cars265.xml',
#  './archive (1)/annotations\\Cars266.xml',
#  './archive (1)/annotations\\Cars267.xml',
#  './archive (1)/annotations\\Cars268.xml',
#  './archive (1)/annotations\\Cars269.xml',
#  './archive (1)/annotations\\Cars27.xml',
#  './archive (1)/annotations\\Cars270.xml',
#  './archive (1)/annotations\\Cars271.xml',
#  './archive (1)/annotations\\Cars272.xml',
#  './archive (1)/annotations\\Cars273.xml',
#  './archive (1)/annotations\\Cars274.xml',
#  './archive (1)/annotations\\Cars275.xml',
#  './archive (1)/annotations\\Cars276.xml',
#  './archive (1)/annotations\\Cars277.xml',
#  './archive (1)/annotations\\Cars278.xml',
#  './archive (1)/annotations\\Cars279.xml',
#  './archive (1)/annotations\\Cars28.xml',
#  './archive (1)/annotations\\Cars280.xml',
#  './archive (1)/annotations\\Cars281.xml',
#  './archive (1)/annotations\\Cars282.xml',
#  './archive (1)/annotations\\Cars283.xml',
#  './archive (1)/annotations\\Cars284.xml',
#  './archive (1)/annotations\\Cars285.xml',
#  './archive (1)/annotations\\Cars286.xml',
#  './archive (1)/annotations\\Cars287.xml',
#  './archive (1)/annotations\\Cars288.xml',
#  './archive (1)/annotations\\Cars289.xml',
#  './archive (1)/annotations\\Cars29.xml',
#  './archive (1)/annotations\\Cars290.xml',
#  './archive (1)/annotations\\Cars291.xml',
#  './archive (1)/annotations\\Cars292.xml',
#  './archive (1)/annotations\\Cars293.xml',
#  './archive (1)/annotations\\Cars294.xml',
#  './archive (1)/annotations\\Cars295.xml',
#  './archive (1)/annotations\\Cars296.xml',
#  './archive (1)/annotations\\Cars297.xml',
#  './archive (1)/annotations\\Cars298.xml',
#  './archive (1)/annotations\\Cars299.xml',
#  './archive (1)/annotations\\Cars3.xml',
#  './archive (1)/annotations\\Cars30.xml',
#  './archive (1)/annotations\\Cars300.xml',
#  './archive (1)/annotations\\Cars301.xml',
#  './archive (1)/annotations\\Cars302.xml',
#  './archive (1)/annotations\\Cars303.xml',
#  './archive (1)/annotations\\Cars304.xml',
#  './archive (1)/annotations\\Cars305.xml',
#  './archive (1)/annotations\\Cars306.xml',
#  './archive (1)/annotations\\Cars307.xml',
#  './archive (1)/annotations\\Cars308.xml',
#  './archive (1)/annotations\\Cars309.xml',
#  './archive (1)/annotations\\Cars31.xml',
#  './archive (1)/annotations\\Cars310.xml',
#  './archive (1)/annotations\\Cars311.xml',
#  './archive (1)/annotations\\Cars312.xml',
#  './archive (1)/annotations\\Cars313.xml',
#  './archive (1)/annotations\\Cars314.xml',
#  './archive (1)/annotations\\Cars315.xml',
#  './archive (1)/annotations\\Cars316.xml',
#  './archive (1)/annotations\\Cars317.xml',
#  './archive (1)/annotations\\Cars318.xml',
#  './archive (1)/annotations\\Cars319.xml',
#  './archive (1)/annotations\\Cars32.xml',
#  './archive (1)/annotations\\Cars320.xml',
#  './archive (1)/annotations\\Cars321.xml',
#  './archive (1)/annotations\\Cars322.xml',
#  './archive (1)/annotations\\Cars323.xml',
#  './archive (1)/annotations\\Cars324.xml',
#  './archive (1)/annotations\\Cars325.xml',
#  './archive (1)/annotations\\Cars326.xml',
#  './archive (1)/annotations\\Cars327.xml',
#  './archive (1)/annotations\\Cars328.xml',
#  './archive (1)/annotations\\Cars329.xml',
#  './archive (1)/annotations\\Cars33.xml',
#  './archive (1)/annotations\\Cars330.xml',
#  './archive (1)/annotations\\Cars331.xml',
#  './archive (1)/annotations\\Cars332.xml',
#  './archive (1)/annotations\\Cars333.xml',
#  './archive (1)/annotations\\Cars334.xml',
#  './archive (1)/annotations\\Cars335.xml',
#  './archive (1)/annotations\\Cars336.xml',
#  './archive (1)/annotations\\Cars337.xml',
#  './archive (1)/annotations\\Cars338.xml',
#  './archive (1)/annotations\\Cars339.xml',
#  './archive (1)/annotations\\Cars34.xml',
#  './archive (1)/annotations\\Cars340.xml',
#  './archive (1)/annotations\\Cars341.xml',
#  './archive (1)/annotations\\Cars342.xml',
#  './archive (1)/annotations\\Cars343.xml',
#  './archive (1)/annotations\\Cars344.xml',
#  './archive (1)/annotations\\Cars345.xml',
#  './archive (1)/annotations\\Cars346.xml',
#  './archive (1)/annotations\\Cars347.xml',
#  './archive (1)/annotations\\Cars348.xml',
#  './archive (1)/annotations\\Cars349.xml',
#  './archive (1)/annotations\\Cars35.xml',
#  './archive (1)/annotations\\Cars350.xml',
#  './archive (1)/annotations\\Cars351.xml',
#  './archive (1)/annotations\\Cars352.xml',
#  './archive (1)/annotations\\Cars353.xml',
#  './archive (1)/annotations\\Cars354.xml',
#  './archive (1)/annotations\\Cars355.xml',
#  './archive (1)/annotations\\Cars356.xml',
#  './archive (1)/annotations\\Cars357.xml',
#  './archive (1)/annotations\\Cars358.xml',
#  './archive (1)/annotations\\Cars359.xml',
#  './archive (1)/annotations\\Cars36.xml',
#  './archive (1)/annotations\\Cars360.xml',
#  './archive (1)/annotations\\Cars361.xml',
#  './archive (1)/annotations\\Cars362.xml',
#  './archive (1)/annotations\\Cars363.xml',
#  './archive (1)/annotations\\Cars364.xml',
#  './archive (1)/annotations\\Cars365.xml',
#  './archive (1)/annotations\\Cars366.xml',
#  './archive (1)/annotations\\Cars367.xml',
#  './archive (1)/annotations\\Cars368.xml',
#  './archive (1)/annotations\\Cars369.xml',
#  './archive (1)/annotations\\Cars37.xml',
#  './archive (1)/annotations\\Cars370.xml',
#  './archive (1)/annotations\\Cars371.xml',
#  './archive (1)/annotations\\Cars372.xml',
#  './archive (1)/annotations\\Cars373.xml',
#  './archive (1)/annotations\\Cars374.xml',
#  './archive (1)/annotations\\Cars375.xml',
#  './archive (1)/annotations\\Cars376.xml',
#  './archive (1)/annotations\\Cars377.xml',
#  './archive (1)/annotations\\Cars378.xml',
#  './archive (1)/annotations\\Cars379.xml',
#  './archive (1)/annotations\\Cars38.xml',
#  './archive (1)/annotations\\Cars380.xml',
#  './archive (1)/annotations\\Cars381.xml',
#  './archive (1)/annotations\\Cars382.xml',
#  './archive (1)/annotations\\Cars383.xml',
#  './archive (1)/annotations\\Cars384.xml',
#  './archive (1)/annotations\\Cars385.xml',
#  './archive (1)/annotations\\Cars386.xml',
#  './archive (1)/annotations\\Cars387.xml',
#  './archive (1)/annotations\\Cars388.xml',
#  './archive (1)/annotations\\Cars389.xml',
#  './archive (1)/annotations\\Cars39.xml',
#  './archive (1)/annotations\\Cars390.xml',
#  './archive (1)/annotations\\Cars391.xml',
#  './archive (1)/annotations\\Cars392.xml',
#  './archive (1)/annotations\\Cars393.xml',
#  './archive (1)/annotations\\Cars394.xml',
#  './archive (1)/annotations\\Cars395.xml',
#  './archive (1)/annotations\\Cars396.xml',
#  './archive (1)/annotations\\Cars397.xml',
#  './archive (1)/annotations\\Cars398.xml',
#  './archive (1)/annotations\\Cars399.xml',
#  './archive (1)/annotations\\Cars4.xml',
#  './archive (1)/annotations\\Cars40.xml',
#  './archive (1)/annotations\\Cars400.xml',
#  './archive (1)/annotations\\Cars401.xml',
#  './archive (1)/annotations\\Cars402.xml',
#  './archive (1)/annotations\\Cars403.xml',
#  './archive (1)/annotations\\Cars404.xml',
#  './archive (1)/annotations\\Cars405.xml',
#  './archive (1)/annotations\\Cars406.xml',
#  './archive (1)/annotations\\Cars407.xml',
#  './archive (1)/annotations\\Cars408.xml',
#  './archive (1)/annotations\\Cars409.xml',
#  './archive (1)/annotations\\Cars41.xml',
#  './archive (1)/annotations\\Cars410.xml',
#  './archive (1)/annotations\\Cars411.xml',
#  './archive (1)/annotations\\Cars412.xml',
#  './archive (1)/annotations\\Cars413.xml',
#  './archive (1)/annotations\\Cars414.xml',
#  './archive (1)/annotations\\Cars415.xml',
#  './archive (1)/annotations\\Cars416.xml',
#  './archive (1)/annotations\\Cars417.xml',
#  './archive (1)/annotations\\Cars418.xml',
#  './archive (1)/annotations\\Cars419.xml',
#  './archive (1)/annotations\\Cars42.xml',
#  './archive (1)/annotations\\Cars420.xml',
#  './archive (1)/annotations\\Cars421.xml',
#  './archive (1)/annotations\\Cars422.xml',
#  './archive (1)/annotations\\Cars423.xml',
#  './archive (1)/annotations\\Cars424.xml',
#  './archive (1)/annotations\\Cars425.xml',
#  './archive (1)/annotations\\Cars426.xml',
#  './archive (1)/annotations\\Cars427.xml',
#  './archive (1)/annotations\\Cars428.xml',
#  './archive (1)/annotations\\Cars429.xml',
#  './archive (1)/annotations\\Cars43.xml',
#  './archive (1)/annotations\\Cars430.xml',
#  './archive (1)/annotations\\Cars431.xml',
#  './archive (1)/annotations\\Cars432.xml',
#  './archive (1)/annotations\\Cars44.xml',
#  './archive (1)/annotations\\Cars45.xml',
#  './archive (1)/annotations\\Cars46.xml',
#  './archive (1)/annotations\\Cars47.xml',
#  './archive (1)/annotations\\Cars48.xml',
#  './archive (1)/annotations\\Cars49.xml',
#  './archive (1)/annotations\\Cars5.xml',
#  './archive (1)/annotations\\Cars50.xml',
#  './archive (1)/annotations\\Cars51.xml',
#  './archive (1)/annotations\\Cars52.xml',
#  './archive (1)/annotations\\Cars53.xml',
#  './archive (1)/annotations\\Cars54.xml',
#  './archive (1)/annotations\\Cars55.xml',
#  './archive (1)/annotations\\Cars56.xml',
#  './archive (1)/annotations\\Cars57.xml',
#  './archive (1)/annotations\\Cars58.xml',
#  './archive (1)/annotations\\Cars59.xml',
#  './archive (1)/annotations\\Cars6.xml',
#  './archive (1)/annotations\\Cars60.xml',
#  './archive (1)/annotations\\Cars61.xml',
#  './archive (1)/annotations\\Cars62.xml',
#  './archive (1)/annotations\\Cars63.xml',
#  './archive (1)/annotations\\Cars64.xml',
#  './archive (1)/annotations\\Cars65.xml',
#  './archive (1)/annotations\\Cars66.xml',
#  './archive (1)/annotations\\Cars67.xml',
#  './archive (1)/annotations\\Cars68.xml',
#  './archive (1)/annotations\\Cars69.xml',
#  './archive (1)/annotations\\Cars7.xml',
#  './archive (1)/annotations\\Cars70.xml',
#  './archive (1)/annotations\\Cars71.xml',
#  './archive (1)/annotations\\Cars72.xml',
#  './archive (1)/annotations\\Cars73.xml',
#  './archive (1)/annotations\\Cars74.xml',
#  './archive (1)/annotations\\Cars75.xml',
#  './archive (1)/annotations\\Cars76.xml',
#  './archive (1)/annotations\\Cars77.xml',
#  './archive (1)/annotations\\Cars78.xml',
#  './archive (1)/annotations\\Cars79.xml',
#  './archive (1)/annotations\\Cars8.xml',
#  './archive (1)/annotations\\Cars80.xml',
#  './archive (1)/annotations\\Cars81.xml',
#  './archive (1)/annotations\\Cars82.xml',
#  './archive (1)/annotations\\Cars83.xml',
#  './archive (1)/annotations\\Cars84.xml',
#  './archive (1)/annotations\\Cars85.xml',
#  './archive (1)/annotations\\Cars86.xml',
#  './archive (1)/annotations\\Cars87.xml',
#  './archive (1)/annotations\\Cars88.xml',
#  './archive (1)/annotations\\Cars89.xml',
#  './archive (1)/annotations\\Cars9.xml',
#  './archive (1)/annotations\\Cars90.xml',
#  './archive (1)/annotations\\Cars91.xml',
#  './archive (1)/annotations\\Cars92.xml',
#  './archive (1)/annotations\\Cars93.xml',
#  './archive (1)/annotations\\Cars94.xml',
#  './archive (1)/annotations\\Cars95.xml',
#  './archive (1)/annotations\\Cars96.xml',
#  './archive (1)/annotations\\Cars97.xml',
#  './archive (1)/annotations\\Cars98.xml',
#  './archive (1)/annotations\\Cars99.xml']

# %%
labels_dict = dict(filepath=[],xmin=[],xmax=[],ymin=[],ymax=[])
for filename in path:

    #filename = path[0]
    info = xet.parse(filename)
    root = info.getroot()
    member_object = root.find('object')
    labels_info = member_object.find('bndbox')
    xmin = int(labels_info.find('xmin').text)
    xmax = int(labels_info.find('xmax').text)
    ymin = int(labels_info.find('ymin').text)
    ymax = int(labels_info.find('ymax').text)
    #print(xmin,xmax,ymin,ymax)
    labels_dict['filepath'].append(filename)
    labels_dict['xmin'].append(xmin)
    labels_dict['xmax'].append(xmax)
    labels_dict['ymin'].append(ymin)
    labels_dict['ymax'].append(ymax)

# %%
df = pd.DataFrame(labels_dict)
df
# Out:
#                                   filepath  xmin  xmax  ymin  ymax
# 0      ./archive (1)/annotations\Cars0.xml   226   419   125   173
# 1      ./archive (1)/annotations\Cars1.xml   134   262   128   160
# 2     ./archive (1)/annotations\Cars10.xml   140   303     5   148
# 3    ./archive (1)/annotations\Cars100.xml   175   214   114   131
# 4    ./archive (1)/annotations\Cars101.xml   167   240   202   220
# ..                                     ...   ...   ...   ...   ...
# 428   ./archive (1)/annotations\Cars95.xml   278   407   182   263
# 429   ./archive (1)/annotations\Cars96.xml   133   261   126   160
# 430   ./archive (1)/annotations\Cars97.xml    98   297   102   191
# 431   ./archive (1)/annotations\Cars98.xml    85   247   196   259
# 432   ./archive (1)/annotations\Cars99.xml    70   262   198   271
#
# [433 rows x 5 columns]

# %%
df.to_csv('labels.csv',index=False)
